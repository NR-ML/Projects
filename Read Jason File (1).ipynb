# %%
import pandas as pd

# %%
import os

# %%
os.listdir()
# Out:
# ['.conda',
#  '.condarc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.spyder-py3',
#  '.VirtualBox',
#  '.vscode',
#  '3D Objects',
#  'AppData',
#  'Application Data',
#  'breast cancer dataset.csv',
#  'Breast cancer SVM.ipynb',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Integrating MySQL with Python - PGD (3).ipynb',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{77524614-5799-11ec-b542-ed9c5c5f05e6}.TM.blf',
#  'NTUSER.DAT{77524614-5799-11ec-b542-ed9c5c5f05e6}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{77524614-5799-11ec-b542-ed9c5c5f05e6}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'pdf reader.ipynb',
#  'pdfreader1.ipynb',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
# ...

# %%
b=[]
for i in os.listdir():
    if ".ipynb" in i:
        b.append(i)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Akash pratap singh'

# %%
# %cd "C:\Users\Akash pratap singh\Downloads"
# Out:
# C:\Users\Akash pratap singh\Downloads

# %%
os.listdir()
# Out:
# ['.RData',
#  '.Rhistory',
#  '08673502.pdf',
#  '1 (1).pdf',
#  '1-s2.0-S001048252100113X-main.pdf',
#  '1.pdf',
#  '10.1038_s41598-021-96031-1-citation.ris',
#  '2.pdf',
#  '20211104_202814.jpg',
#  '20CricketTeamSelectionUsingArtificialIntelligence.doc',
#  '2282-Article Text-6812-1-10-20201030.pdf',
#  'af-998.zip',
#  'air travel dataset.xlsx',
#  'airline_sas_file.sas7bdat',
#  'Akash Excel File.xlsx',
#  'Akash Nave Byes',
#  'akash template.png',
#  'Anaconda3-2020.02-Windows-x86_64.exe',
#  'AnyDesk.exe',
#  'Apps_data.csv',
#  'archive (1).zip',
#  'archive (2).zip',
#  'archive (3).zip',
#  'archive (4).zip',
#  'archive (5).zip',
#  'archive (6).zip',
#  'archive (7).zip',
#  'archive (8).zip',
#  'archive (9).zip',
#  'archive.zip',
#  'Assignment -MSc R programming.docx',
#  'ASSIGNMENT NO 4 ( Defining Function) (1).ipynb',
#  'ASSIGNMENT NO 4 ( Defining Function).ipynb',
#  'Assingment1.R',
#  'Assingment2 ggplot (1).R',
#  'Assingment2 ggplot.R',
# ...

# %%
a=[]
for i in os.listdir():
    if ".json" in i:
        a.append(i)

# %%
a
# Out:
# ['employee_data.json', 'google_addr_file.json', 'nested_tweets04.json']

# %%
a[0]
# Out:
# 'employee_data.json'

# %%
for i,j in zip(a,w):
    globals()[j]=pd.read_json(i)

# %%
w="qpm"

# %%
q
# Out:
#                                               features
# 0    {'candidate': {'first_name': 'Margaret', 'last...
# 1    {'candidate': {'first_name': 'Michael', 'last_...
# 2    {'candidate': {'first_name': 'Brenda', 'last_n...
# 3    {'candidate': {'first_name': 'Joseph', 'last_n...
# 4    {'candidate': {'first_name': 'Laura', 'last_na...
# ..                                                 ...
# 495  {'candidate': {'first_name': 'Robert', 'last_n...
# 496  {'candidate': {'first_name': 'Lucas', 'last_na...
# 497  {'candidate': {'first_name': 'Kimberly', 'last...
# 498  {'candidate': {'first_name': 'Karla', 'last_na...
# 499  {'candidate': {'first_name': 'Mrs.', 'last_nam...
#
# [500 rows x 1 columns]

# %%
p
# Out:
#                                      timelineObjects
# 0  {'activitySegment': {'startLocation': {'latitu...
# 1  {'placeVisit': {'location': {'latitudeE7': 514...
# 2  {'activitySegment': {'startLocation': {'latitu...
# 3  {'placeVisit': {'location': {'latitudeE7': 396...
# 4  {'activitySegment': {'startLocation': {'latitu...
# 5  {'placeVisit': {'location': {'latitudeE7': 394...

# %%
m
# Out:
#                                                     0
# 0                {"retweeted": ["Nothing_retweeted"]}
# 1   {"retweeted": [{"created_at": "Mon Jul 13 01:2...
# 2                {"retweeted": ["Nothing_retweeted"]}
# 3                {"retweeted": ["Nothing_retweeted"]}
# 4   {"retweeted": [{"created_at": "Sat Jul 11 18:5...
# 5   {"retweeted": [{"created_at": "Sun Jul 12 22:5...
# 6   {"retweeted": [{"created_at": "Sun Jul 12 19:0...
# 7                {"retweeted": ["Nothing_retweeted"]}
# 8   {"retweeted": [{"created_at": "Fri Jul 10 22:1...
# 9   {"retweeted": [{"created_at": "Mon Sep 30 03:5...
# 10  {"retweeted": [{"created_at": "Sun Jul 12 15:4...
# 11  {"retweeted": [{"created_at": "Mon Jul 13 00:3...
# 12  {"retweeted": [{"created_at": "Mon Jul 13 00:5...
# 13  {"retweeted": [{"created_at": "Mon Jul 13 01:1...
# 14  {"retweeted": [{"created_at": "Mon Jul 13 01:1...
# 15               {"retweeted": ["Nothing_retweeted"]}
# ...

# %%
pd
